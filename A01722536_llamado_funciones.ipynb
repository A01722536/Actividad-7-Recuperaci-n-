# %%
import A01722536_funciones as fun

# %%
funcion_1=fun.funcion_1("Mallorca.xlsx")
funcion_1
# Out:
#                         id       scrape_id last_scraped       source  \
# 0                    69998  20241214212418   2024-12-15  city scrape
# 1                   106833  20241214212418   2024-12-15  city scrape
# 2                   159218  20241214212418   2024-12-15  city scrape
# 3                   164185  20241214212418   2024-12-15  city scrape
# 4                   166820  20241214212418   2024-12-15  city scrape
# ...                    ...             ...          ...          ...
# 16862  1308224357787269888  20241214212418   2024-12-15  city scrape
# 16863  1308461808126489088  20241214212418   2024-12-15  city scrape
# 16864  1308461814550170880  20241214212418   2024-12-15  city scrape
# 16865  1308461822310863872  20241214212418   2024-12-15  city scrape
# 16866  1308461864517467904  20241214212418   2024-12-15  city scrape
#
#                                                     name    host_id host_name  \
# 0                      COZY HIDEAWAY  LOFT... MI AMOR...     353156       Lor
# 1                      Villa with a big pool in Mallorca     551974     Xisco
# 2                           Farmhouse in Nature -ET-3025     763897   Gabriel
# 3          Corazón de Palma-Habitación con baño privado.     788123     Maria
# 4      Guest House with Great sea views - Principal Room     794829      Toni
# ...                                                  ...        ...       ...
# 16862                         Very Cosy and very central  588497055   Martina
# 16863                                       Habitación 5  587006009    Holidu
# 16864                                       Habitación 4  587006009    Holidu
# 16865                                       Habitación 3  587006009    Holidu
# 16866                                        Apartamento  587006009    Holidu
#
#       host_since             host_location host_response_time  ...  \
# 0     2011-01-19              Palma, Spain     within an hour  ...
# 1     2011-05-02  Palma de Mallorca, Spain                NaN  ...
# 2     2011-06-30               Inca, Spain     within an hour  ...
# 3     2011-07-07  Costa d'en Blanes, Spain     within an hour  ...
# 4     2011-07-08   Balearic Islands, Spain     within an hour  ...
# ...          ...                       ...                ...  ...
# 16862 2024-07-09              Palma, Spain     within an hour  ...
# 16863 2024-07-02              Palma, Spain     within an hour  ...
# 16864 2024-07-02              Palma, Spain     within an hour  ...
# 16865 2024-07-02              Palma, Spain     within an hour  ...
# 16866 2024-07-02              Palma, Spain     within an hour  ...
#
#        last_review  review_scores_rating review_scores_accuracy  \
# 0       2024-10-26                  4.95                   4.92
# 1       2024-09-11                  4.89                   4.81
# 2       2024-10-27                  4.92                   4.88
# 3       2024-10-26                  4.75                   4.72
# 4       2024-10-08                  4.67                   4.75
# ...            ...                   ...                    ...
# 16862          NaT                   NaN                    NaN
# 16863          NaT                   NaN                    NaN
# 16864          NaT                   NaN                    NaN
# 16865          NaT                   NaN                    NaN
# 16866          NaT                   NaN                    NaN
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.93                   4.95
# 1                           4.81                   4.89
# 2                           4.93                   4.96
# 3                           4.64                   4.93
# 4                           4.35                   4.87
# ...                          ...                    ...
# 16862                        NaN                    NaN
# 16863                        NaN                    NaN
# 16864                        NaN                    NaN
# 16865                        NaN                    NaN
# 16866                        NaN                    NaN
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            4.97                   4.89                4.81
# 1                            4.92                   4.52                4.63
# 2                            4.95                   4.82                4.75
# 3                            4.90                   4.93                4.68
# 4                            4.91                   4.94                4.60
# ...                           ...                    ...                 ...
# 16862                         NaN                    NaN                 NaN
# 16863                         NaN                    NaN                 NaN
# 16864                         NaN                    NaN                 NaN
# 16865                         NaN                    NaN                 NaN
# 16866                         NaN                    NaN                 NaN
#
#       instant_bookable calculated_host_listings_count
# 0                    t                              2
# 1                    f                              1
# 2                    f                              1
# 3                    f                              1
# 4                    t                              4
# ...                ...                            ...
# 16862                f                              1
# 16863                t                             83
# 16864                t                             83
# 16865                t                             83
# 16866                t                             83
#
# [16867 rows x 50 columns]

# %%
funcion_2=fun.funcion_2(funcion_1)
funcion_2
# Out:
# /Users/personal/Desktop/Curso Alfredo/A01722536_funciones.py:30: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(1000001, inplace=True)
# /Users/personal/Desktop/Curso Alfredo/A01722536_funciones.py:28: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(1111111, inplace=True)
#                         id       scrape_id last_scraped       source  \
# 0                    69998  20241214212418   2024-12-15  city scrape
# 1                   106833  20241214212418   2024-12-15  city scrape
# 2                   159218  20241214212418   2024-12-15  city scrape
# 3                   164185  20241214212418   2024-12-15  city scrape
# 4                   166820  20241214212418   2024-12-15  city scrape
# ...                    ...             ...          ...          ...
# 16862  1308224357787269888  20241214212418   2024-12-15  city scrape
# 16863  1308461808126489088  20241214212418   2024-12-15  city scrape
# 16864  1308461814550170880  20241214212418   2024-12-15  city scrape
# 16865  1308461822310863872  20241214212418   2024-12-15  city scrape
# 16866  1308461864517467904  20241214212418   2024-12-15  city scrape
#
#                                                     name    host_id host_name  \
# 0                      COZY HIDEAWAY  LOFT... MI AMOR...     353156       Lor
# 1                      Villa with a big pool in Mallorca     551974     Xisco
# 2                           Farmhouse in Nature -ET-3025     763897   Gabriel
# 3          Corazón de Palma-Habitación con baño privado.     788123     Maria
# 4      Guest House with Great sea views - Principal Room     794829      Toni
# ...                                                  ...        ...       ...
# 16862                         Very Cosy and very central  588497055   Martina
# 16863                                       Habitación 5  587006009    Holidu
# 16864                                       Habitación 4  587006009    Holidu
# 16865                                       Habitación 3  587006009    Holidu
# 16866                                        Apartamento  587006009    Holidu
#
#       host_since             host_location host_response_time  ...  \
# 0     2011-01-19              Palma, Spain     within an hour  ...
# 1     2011-05-02  Palma de Mallorca, Spain         Valor Nulo  ...
# 2     2011-06-30               Inca, Spain     within an hour  ...
# 3     2011-07-07  Costa d'en Blanes, Spain     within an hour  ...
# 4     2011-07-08   Balearic Islands, Spain     within an hour  ...
# ...          ...                       ...                ...  ...
# 16862 2024-07-09              Palma, Spain     within an hour  ...
# 16863 2024-07-02              Palma, Spain     within an hour  ...
# 16864 2024-07-02              Palma, Spain     within an hour  ...
# 16865 2024-07-02              Palma, Spain     within an hour  ...
# 16866 2024-07-02              Palma, Spain     within an hour  ...
#
#                last_review  review_scores_rating review_scores_accuracy  \
# 0      2024-10-26 00:00:00                  4.95                   4.92
# 1      2024-09-11 00:00:00                  4.89                   4.81
# 2      2024-10-27 00:00:00                  4.92                   4.88
# 3      2024-10-26 00:00:00                  4.75                   4.72
# 4      2024-10-08 00:00:00                  4.67                   4.75
# ...                    ...                   ...                    ...
# 16862           Valor Nulo            1111111.00             1000001.00
# 16863           Valor Nulo            1111111.00             1000001.00
# 16864           Valor Nulo            1111111.00             1000001.00
# 16865           Valor Nulo            1111111.00             1000001.00
# 16866           Valor Nulo            1111111.00             1000001.00
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                           4.93                   4.95
# 1                           4.81                   4.89
# 2                           4.93                   4.96
# 3                           4.64                   4.93
# 4                           4.35                   4.87
# ...                          ...                    ...
# 16862                 1111111.00             1000001.00
# 16863                 1111111.00             1000001.00
# 16864                 1111111.00             1000001.00
# 16865                 1111111.00             1000001.00
# 16866                 1111111.00             1000001.00
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                            4.97                   4.89                4.81
# 1                            4.92                   4.52                4.63
# 2                            4.95                   4.82                4.75
# 3                            4.90                   4.93                4.68
# 4                            4.91                   4.94                4.60
# ...                           ...                    ...                 ...
# 16862                  1000001.00             1000001.00          1111111.00
# 16863                  1000001.00             1000001.00          1111111.00
# 16864                  1000001.00             1000001.00          1111111.00
# 16865                  1000001.00             1000001.00          1111111.00
# 16866                  1000001.00             1000001.00          1111111.00
#
#       instant_bookable calculated_host_listings_count
# 0                    t                              2
# 1                    f                              1
# 2                    f                              1
# 3                    f                              1
# 4                    t                              4
# ...                ...                            ...
# 16862                f                              1
# 16863                t                             83
# 16864                t                             83
# 16865                t                             83
# 16866                t                             83
#
# [16867 rows x 50 columns]

# %%
funcion_3=fun.funcion_3(funcion_2)
funcion_3
# Out:
# Por Columna:
#            id                                0
# scrape_id                         0
# last_scraped                      0
# source                            0
# name                              0
# host_id                           0
# host_name                         0
# host_since                        0
# host_location                     0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_listings_count               0
# host_total_listings_count         0
# host_verifications                0
# host_has_profile_pic              0
# host_identity_verified            0
# neighbourhood                     0
# neighbourhood_cleansed            0
# neighbourhood_group_cleansed      0
# latitude                          0
# longitude                         0
# property_type                     0
# room_type                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# price                             0
# has_availability                  0
# availability_30                   0
# availability_60                   0
# availability_90                   0
# availability_365                  0
# calendar_last_scraped             0
# number_of_reviews                 0
# number_of_reviews_ltm             0
# number_of_reviews_l30d            0
# first_review                      0
# last_review                       0
# review_scores_rating              0
# review_scores_accuracy            0
# review_scores_cleanliness         0
# review_scores_checkin             0
# review_scores_communication       0
# review_scores_location            0
# review_scores_value               0
# instant_bookable                  0
# calculated_host_listings_count    0
# dtype: int64
# Por DataFrame:
#            0

# %%
funcion_4=fun.funcion_4(funcion_2)
funcion_4
# Out:
#       last_scraped       source  \
# 0       2024-12-15  city scrape
# 1       2024-12-15  city scrape
# 2       2024-12-15  city scrape
# 3       2024-12-15  city scrape
# 4       2024-12-15  city scrape
# ...            ...          ...
# 16862   2024-12-15  city scrape
# 16863   2024-12-15  city scrape
# 16864   2024-12-15  city scrape
# 16865   2024-12-15  city scrape
# 16866   2024-12-15  city scrape
#
#                                                     name host_name host_since  \
# 0                      COZY HIDEAWAY  LOFT... MI AMOR...       Lor 2011-01-19
# 1                      Villa with a big pool in Mallorca     Xisco 2011-05-02
# 2                           Farmhouse in Nature -ET-3025   Gabriel 2011-06-30
# 3          Corazón de Palma-Habitación con baño privado.     Maria 2011-07-07
# 4      Guest House with Great sea views - Principal Room      Toni 2011-07-08
# ...                                                  ...       ...        ...
# 16862                         Very Cosy and very central   Martina 2024-07-09
# 16863                                       Habitación 5    Holidu 2024-07-02
# 16864                                       Habitación 4    Holidu 2024-07-02
# 16865                                       Habitación 3    Holidu 2024-07-02
# 16866                                        Apartamento    Holidu 2024-07-02
#
#                   host_location host_response_time host_is_superhost  \
# 0                  Palma, Spain     within an hour                 t
# 1      Palma de Mallorca, Spain         Valor Nulo                 f
# 2                   Inca, Spain     within an hour                 t
# 3      Costa d'en Blanes, Spain     within an hour        Valor Nulo
# 4       Balearic Islands, Spain     within an hour                 f
# ...                         ...                ...               ...
# 16862              Palma, Spain     within an hour                 f
# 16863              Palma, Spain     within an hour                 f
# 16864              Palma, Spain     within an hour                 f
# 16865              Palma, Spain     within an hour                 f
# 16866              Palma, Spain     within an hour                 f
#
#        host_verifications host_has_profile_pic  ... number_of_reviews_ltm  \
# 0      ['email', 'phone']                    t  ...                     3
# 1      ['email', 'phone']                    t  ...                     8
# 2      ['email', 'phone']                    t  ...                    31
# 3               ['phone']                    t  ...                    12
# 4      ['email', 'phone']                    t  ...                    33
# ...                   ...                  ...  ...                   ...
# 16862  ['email', 'phone']                    t  ...                     0
# 16863  ['email', 'phone']                    t  ...                     0
# 16864  ['email', 'phone']                    t  ...                     0
# 16865  ['email', 'phone']                    t  ...                     0
# 16866  ['email', 'phone']                    t  ...                     0
#
#       number_of_reviews_l30d review_scores_rating review_scores_accuracy  \
# 0                          0                  NaN                    NaN
# 1                          0                  NaN                    NaN
# 2                          0                  NaN                    NaN
# 3                          0                  NaN                    NaN
# 4                          0                  NaN                    NaN
# ...                      ...                  ...                    ...
# 16862                      0                  NaN                    NaN
# 16863                      0                  NaN                    NaN
# 16864                      0                  NaN                    NaN
# 16865                      0                  NaN                    NaN
# 16866                      0                  NaN                    NaN
#
#       review_scores_cleanliness review_scores_checkin  \
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
# ...                         ...                   ...
# 16862                       NaN                   NaN
# 16863                       NaN                   NaN
# 16864                       NaN                   NaN
# 16865                       NaN                   NaN
# 16866                       NaN                   NaN
#
#       review_scores_communication review_scores_location review_scores_value  \
# 0                             NaN                    NaN                 NaN
# 1                             NaN                    NaN                 NaN
# 2                             NaN                    NaN                 NaN
# 3                             NaN                    NaN                 NaN
# 4                             NaN                    NaN                 NaN
# ...                           ...                    ...                 ...
# 16862                         NaN                    NaN                 NaN
# 16863                         NaN                    NaN                 NaN
# 16864                         NaN                    NaN                 NaN
# 16865                         NaN                    NaN                 NaN
# 16866                         NaN                    NaN                 NaN
#
#       calculated_host_listings_count
# 0                                  2
# 1                                  1
# 2                                  1
# 3                                  1
# 4                                  4
# ...                              ...
# 16862                              1
# 16863                             83
# 16864                             83
# 16865                             83
# 16866                             83
#
# [16867 rows x 50 columns]
